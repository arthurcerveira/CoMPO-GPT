# %%
import os
from pathlib import Path
import pandas as pd
import numpy as np
from rdkit import RDLogger
import matplotlib.pyplot as plt
import seaborn as sns
import sys

import random

# Set seed for reproducibility
random.seed(42)
np.random.seed(42)

from smiles_utils import filter_and_canonicalize, AllowedSmilesCharDictionary, split_charged_mol

# Add qsar module to path for chemprop_callback
CURRENT_DIR = Path('.').resolve()
sys.path.append(str(CURRENT_DIR / ".." / "qsar"))

from assessment.chemprop_callback import predict_activity_chemprop

smiles_char_dict = AllowedSmilesCharDictionary()

def clean_smile(smiles):
    # only keep reasonably sized molecules
    if 5 > len(smiles) or len(smiles) > 200:
        return None
    
    smiles = split_charged_mol(smiles)

    if not smiles_char_dict.allowed(smiles):
        return None
    
    filtered_smiles = filter_and_canonicalize(smiles)
    return filtered_smiles[0] if filtered_smiles else None

# Suppress warnings
lg = RDLogger.logger()
lg.setLevel(RDLogger.CRITICAL)

import torch
torch.cuda.is_available()
# Out:
# True

# %%
ASSAYS_DIR = CURRENT_DIR / ".." / "data" / "Assays-pXC50"

pal=list(sns.color_palette("tab10"))

# %% [markdown]
# ### Run Chemprop models for each target

# %%
from pandarallel import pandarallel

pandarallel.initialize(progress_bar=False)

# load qsar models for each target
targets = ['AChE', 'D2R', 'D3R', '_5HT2A', 'MAOB']
predicted_activities_all = dict()
predicted_activities_sample = dict()
active_molecules = dict()

filtered_smiles_all = dict()
filtered_smiles_sample = dict()

for target in targets:
    # load active molecules dataset for each target
    X = pd.read_csv(ASSAYS_DIR / f'{target}.csv')
    X['SMILES'] = X['SMILES'].parallel_apply(clean_smile)
    X = X.dropna() # .sample(1500)

    filtered_smiles_all[target] = X
    filtered_smiles_sample[target] = X.sample(1500)

for target_model in targets:
    print(f'Loading {target_model} model')
    predicted_activities_all[target_model] = dict()
    predicted_activities_sample[target_model] = dict()

    for target_dataset in targets:
        print(f'Predicting activity for {target_dataset} dataset')

        X = filtered_smiles_all[target_dataset]
        smiles = X['SMILES'].to_list()

        # Use the new predict_activity_chemprop function
        preds = predict_activity_chemprop(smiles, target_model)
        predicted_activities_all[target_model][target_dataset] = np.array(preds)

        X = filtered_smiles_sample[target_dataset]
        smiles = X['SMILES'].to_list()
        preds = predict_activity_chemprop(smiles, target_model)
        predicted_activities_sample[target_model][target_dataset] = np.array(preds)
# Out:
# INFO: Pandarallel will run on 12 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# Loading AChE model
# Predicting activity for AChE dataset
# Predicting activity for D2R dataset
# Predicting activity for D3R dataset
# Predicting activity for _5HT2A dataset
# Predicting activity for MAOB dataset
# Loading D2R model
# Predicting activity for AChE dataset
# Predicting activity for D2R dataset
# Predicting activity for D3R dataset
# Predicting activity for _5HT2A dataset
# Predicting activity for MAOB dataset
# Loading D3R model
# Predicting activity for AChE dataset
# Predicting activity for D2R dataset
# Predicting activity for D3R dataset
# Predicting activity for _5HT2A dataset
# Predicting activity for MAOB dataset
# Loading _5HT2A model
# Predicting activity for AChE dataset
# Predicting activity for D2R dataset
# Predicting activity for D3R dataset
# Predicting activity for _5HT2A dataset
# ...

# %% [markdown]
# ### Plot the target activity correlation

# %%
# plot a scatter plot of the predicted activities for each target
# each row is a target model, each column is a target dataset
# the x axis is the predicted activity of the target model, the y axis is the predicted activity of the target dataset
target_labels = {
    "Unconditional": "Unconditional",
    "D2R": "D2R",
    "D3R": "D3R",
    "_5HT2A": "5-HT2AR",
    "AChE": "AChE",
    "MAOB": "MAO-B",
}

fig, axes = plt.subplots(len(targets), len(targets), figsize=(22, 22), dpi=120)

# Set the one label for each row and column
for i, target_model in enumerate(targets):
    axes[i, 0].set_ylabel(
        target_labels[target_model] + ' predicted activity', fontsize=16, labelpad=10,)
    axes[-1, i].set_xlabel(target_labels[targets[i]] + ' true activity', fontsize=16, labelpad=10)

for i, target_model in enumerate(targets):
    for j, target_dataset in enumerate(targets):
        # axes[i, j].scatter(
        #     predicted_activities[target_model][target_dataset], 
        #     filtered_smiles[target_dataset]['pXC50'],
        #     alpha=0.3,
        #     color=pal[i]
        # )
        axes[i, j].hexbin(
            predicted_activities_sample[target_model][target_dataset], 
            filtered_smiles_sample[target_dataset]['pXC50'], gridsize=20, cmap='Blues',
        )

        target_model_label = target_labels[target_model]
        target_dataset_label = target_labels[target_dataset]

        axes[i, j].set_title(f'{target_model_label} prediction X {target_dataset_label} activity', fontsize=15, color='#333333')
        # axes[i, j].set_xlabel(f'{target_model_label} predicted activity (pXC50)', fontsize=14)
        # axes[i, j].set_ylabel(f'{target_dataset_label} true activity (pXC50)', fontsize=14)

        # calculate the correlation coefficient
        correlation = np.corrcoef(
            predicted_activities_sample[target_model][target_dataset], 
            filtered_smiles_sample[target_dataset]['pXC50']
        )[0, 1]

        axes[i, j].text(0.5, 0.9, f'Correlation: {correlation:.2f}', 
                        horizontalalignment='center',
                        verticalalignment='center',
                        transform=axes[i, j].transAxes,
                        fontsize=16, color='black',
                        # Set italic
                        fontstyle='italic',
                        bbox=dict(facecolor='white', alpha=0.3, edgecolor='black'))
        
        # Remove x and y axis labels
        axes[i, j].set_xticks([])
        axes[i, j].set_yticks([])

        # Set frame color
        for spine in axes[i, j].spines.values():
            spine.set_edgecolor('#aaaaaa')
            spine.set_linewidth(0.5)


plt.tight_layout()
fig.subplots_adjust(hspace=0.2, wspace=0.2)

plt.savefig('predicted_vs_true_activities.svg', format='svg', bbox_inches='tight', dpi=300)

plt.show()

# %%
# !pip install matplotlib_venn

# %%
from matplotlib_venn import venn2
import matplotlib.pyplot as plt

# Define disease-target pairs
disease_pairs = {
    "alzheimer": ("AChE", "MAOB"),
    "schizophrenia": ("D2R", "_5HT2A"),
    "parkinson": ("D2R", "D3R"),
}

disease_titles = {
    "alzheimer": "(a) Alzheimer's disease",
    "schizophrenia": "(b) Schizophrenia disorder",
    "parkinson": "(c) Parkinson's disease"
}

target_labels = {
    "D2R": "D2R",
    "D3R": "D3R",
    "_5HT2A": "5-HT2AR",
    "AChE": "AChE",
    "MAOB": "MAO-B",
}

disease_colors = {
    "alzheimer": {
        "AChE": "#b4a7d6",
        "MAOB": "#9fc5e8"
    },
    "schizophrenia": {
        "D2R": "#ea9999",
        "_5HT2A": "#ffe599"
    },
    "parkinson": {
        "D2R": "#b6d7a8",
        # "D3R": "#a4c2f4"
        "D3R": "#d5a6bd"
    }
}

# Activity threshold
ACTIVITY_THRESHOLD = 7.0

def create_venn_diagram(disease_name, target1, target2, ax=None):
    """
    Draw a Venn diagram on the provided axes showing overlap of active molecules
    between two targets. Returns the computed sets and counts.
    """

    # --- Retrieve datasets ---
    target1_data = filtered_smiles_all[target1].copy()
    target2_data = filtered_smiles_all[target2].copy()

    # --- Add cross-model predictions (align by order) ---
    # predicted activites structure: {target_model: {target_dataset: [preds]}}
    target1_data['t1_mols_pred_by_t2_model'] = predicted_activities_all[target2][target1]
    target2_data['t2_mols_pred_by_t1_model'] = predicted_activities_all[target1][target2]

    target_data = target1_data.merge(
        target2_data, on='SMILES', how='outer', suffixes=('_target1', '_target2')
    )

    target_data["pXC50_target1"] = target_data["pXC50_target1"].fillna(
        target_data["t2_mols_pred_by_t1_model"]
    ).drop(columns=["t2_mols_pred_by_t1_model"])
    target_data["pXC50_target2"] = target_data["pXC50_target2"].fillna(
        target_data["t1_mols_pred_by_t2_model"]
    ).drop(columns=["t1_mols_pred_by_t2_model"])

    # --- Identify active molecules (ground truth) ---
    target_data["target1_active"] = target_data["pXC50_target1"] > ACTIVITY_THRESHOLD
    target_data["target2_active"] = target_data["pXC50_target2"] > ACTIVITY_THRESHOLD

    # --- Define molecule sets (using SMILES for consistent IDs) ---
    left_set = set(
        target_data.loc[
            target_data["target1_active"] & ~target_data["target2_active"], 'SMILES'
        ]
    )
    right_set = set(
        target_data.loc[
            target_data["target2_active"] & ~target_data["target1_active"], 'SMILES'
        ]
    )
    intersection = set(
        target_data.loc[
            target_data["target1_active"] & target_data["target2_active"], 'SMILES'
        ]
    )

    # --- Draw Venn ---
    target1_label = target_labels[target1]
    target2_label = target_labels[target2]
    set_colors = [
        disease_colors[disease_name][target1],
        disease_colors[disease_name][target2],
    ]

    venn2(
        subsets=[len(left_set), len(right_set), len(intersection)],
        set_labels=(
            f"Active for {target1_label}\n(pred. inactive by {target2_label} model)",
            f"Active for {target2_label}\n(pred. inactive by {target1_label} model)"
        ),
        set_colors=set_colors,
        subset_label_formatter=lambda x: f"{x:,}\nmolecules",
        ax=ax
    )

    # Set font size of the labels to 8
    for text in ax.texts:
        text.set_fontsize(8)
        text.set_color('#333333')

    # --- Statistics summary (consistent with diagram) ---
    stats_text = (
        f"Venn Statistics:\n"
        f"• {target1} active & pred. inactive by {target2}: {len(left_set)}\n"
        f"• {target2} active & pred. inactive by {target1}: {len(right_set)}\n"
        f"• Active & predicted active in both: {len(intersection)}\n"
    )
    pct_target1_active_both = (len(intersection) / len(left_set.union(intersection))) * 100
    pct_target2_active_both = (len(intersection) / len(right_set.union(intersection))) * 100
    proportions_text = (
        f"Proportions:\n"
        f"• {target1} active & also active in {target2}: {pct_target1_active_both:.2f}%\n"
        f"• {target2} active & also active in {target1}: {pct_target2_active_both:.2f}%\n"
    )
    stats_text += proportions_text
    print(stats_text)

    if ax is not None:
        ax.set_title(
            f"{disease_titles[disease_name]} — {target1_label} & {target2_label}",  # \n"
            # f"pXC50 > {ACTIVITY_THRESHOLD}",
            fontsize=9,
            color='#333333',
        )

    return {
        'left_set': left_set,
        'right_set': right_set,
        'intersection': intersection,
        'n_left': len(left_set),
        'n_right': len(right_set),
        'n_intersection': len(intersection),
    }

# Create a single figure with three subplots (one per disease)
fig, axes = plt.subplots(3, 1, figsize=(6, 10), dpi=200)
results = {}

# Fix display order
ordered_diseases = ["alzheimer", "schizophrenia", "parkinson"]

for ax, disease in zip(axes, ordered_diseases):
    target1, target2 = disease_pairs[disease]
    results[disease] = create_venn_diagram(disease, target1, target2, ax=ax)

plt.tight_layout()
plt.savefig('Set-Overlap.svg', dpi=200)
plt.show()
